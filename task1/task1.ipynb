# %%
# !pip install -r requirements.txt !pip install -r requ

# %%
import pandas as pd

# %%
df = pd.read_csv("/home/viacheslav/Desktop/jobs/data_engineer/test.csv")

# %%
df_deduplicate = df.drop_duplicates()

# %%
df_deduplicated_by_bonus_issue_id = df.loc[df.groupby('bonus_issue_id')['updated_at'].idxmax()]

# %%
df_deduplicated_by_bonus_issue_id
# Out:
#      bonus_issue_id operation  user_id        stage  \
# 440         1922187    update   878457      expired
# 120         1922698    update    10936      expired
# 366         1922953    update   461884         lost
# 422         1925766    update  1001138     canceled
# 242         1925818    update   490519     canceled
# ..              ...       ...      ...          ...
# 98          1935854    update  1307708         lost
# 99          1935855    update   298654  handle_bets
# 101         1935856    update  1325433  handle_bets
# 107         1935857    update   556114  handle_bets
# 109         1935858    update  1087835  handle_bets
#
#                                title currency            created_at  \
# 440                    AUD 3 Witches      AUD  2024-02-10T16:09:38Z
# 120                    AUD 3 Witches      AUD  2024-02-11T11:20:46Z
# 366                    AUD 3 Witches      AUD  2024-02-11T21:10:47Z
# ...

# %%
df_deduplicate
# Out:
#      bonus_issue_id operation  user_id        stage                  title  \
# 0           1934835    update  1345450         lost  2nd Deposit FS result
# 1           1935820    update   453548  handle_bets    King Billy VIP fs 8
# 3           1935821    update   343152  handle_bets     King Billy VIP fs2
# 5           1935798    update   254560         lost         Free Chips 100
# 6           1935822    update  1286036  handle_bets     King Billy VIP fs5
# ..              ...       ...      ...          ...                    ...
# 993         1930902    update   496835  handle_bets          Free Chips 20
# 995         1930978    update   496835  handle_bets          Free Chips 20
# 997         1930978    update   496835         lost          Free Chips 20
# 998         1927976    update   640963         lost          Free Chips 20
# 999         1930140    update  1340061  handle_bets          Free Chips 20
#
# ...
